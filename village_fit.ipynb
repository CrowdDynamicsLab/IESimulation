# %%
import os
import json

import pandas as pd
import numpy as np
import networkx as nx
from matplotlib import pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from itertools import chain

from comparison.wasserstein import emd

# %%
import matplotlib as mpl
import matplotlib.font_manager as font_manager
from matplotlib import rcParams

#font_path = '/home/andyclee/.fonts/LinLibertine_R.ttf'  # Your font path goes here
#font_manager.fontManager.addfont(font_path)
#prop = font_manager.FontProperties(fname=font_path)

#mpl.rcParams['font.family'] = 'Linux Libertine'

# %%
def calc_dists(arr, attr_dict, kappa):

    opairs = []

    max_edges = (kappa - 1) * (kappa - 2) / 2
    three_walks = (arr @ arr) @ arr
    for v, vtype in attr_dict.items():
        deg = sum(arr[v])

        assort = 0
        for u, con in enumerate(arr[v]):
            if con and attr_dict[u] == attr_dict[v]:
                assort += 1
            elif con and attr_dict[u] != attr_dict[v]:
                assort -= 1

        if deg == 0:
            assort = 0
        else:
            assort = assort / deg

        ccoeff = 0
        if deg <= 1:
            ccoeff = 0
        else:
            ccoeff = (three_walks[v][v] / 2) / (deg * (deg - 1))

        opairs.append( ( (assort + 1) / 2, ccoeff) )

    dist_map = {}
    for op in opairs:
        if op in dist_map:
            dist_map[op] += 1
        else:
            dist_map[op] = 1

    dist = []
    for op, freq in dist_map.items():
        dist.append( (op, freq / len(attr_dict)) )

    return dist

def avg_dists(dists):
    dist_freq = {}
    for d in dists:
        for op, freq in d:
            if op in dist_freq:
                dist_freq[op] += freq
            else:
                dist_freq[op] = freq
    for op, freq in dist_freq.items():
        dist_freq[op] = freq / len(dists)

    return [ (op, freq) for op, freq in dist_freq.items() ]

# %%
# try a new metric that has global and local
def triangle_count(adj_mat):
    return np.trace(np.linalg.matrix_power(adj_mat, 3)) / 6

def assortativity_coeff(adj_mat, types):
    n = len(adj_mat)
    
    # 2 times the edge count, based on paper normalization
    m = np.sum(adj_mat)
    e = np.zeros((2, 2))
    for i in range(n):
        for j in range(n):
            if adj_mat[i][j] != 1:
                continue
            
            if types[i] == types[j] and types[i] == -1:
                e[0][0] += 1
            elif types[i] != types[j] and types[i] == -1:
                e[0][1] += 1
            elif types[i] != types[j] and types[i] == 1:
                e[1][0] += 1
            elif types[i] == types[j] and types[i] == 1:
                e[1][1] += 1
    
    e = e / m
    e_square = np.square(e)
    es_sum = np.sum(e_square)
    e_trace = np.trace(e)
    assort = (e_trace - es_sum) / (1 - es_sum)
    return (assort + 1) / 2

def ntwk_metric(dist1, tc1, assort1, dist2, tc2, assort2):
    distr_metric = emd(dist1, dist2)
    
    tc_diff = abs(tc1 - tc2) / (tc1 + tc2) # https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error
    assort_diff = abs(assort1 - assort2) / (assort1 + assort2)
    global_diff = (tc_diff + assort_diff) # don't divide by 2 because distributional metric is between [0, 2]
    
    return (distr_metric + global_diff) / 2

# %%
vill_list_old = chain(range(12),range(13, 21),range(22, 77))

vill_list = [x+1 for x in vill_list_old]

#vill_list = [10]

sc_old = range(17)
ho_old = range(17)

sc_list = [x/16 for x in sc_old]
ho_list = [x/16 for x in ho_old]

k = 10

# %%
def get_max_degree(arr):
    G_nx = nx.from_numpy_array(arr)
    degrees = [val for (node, val) in G_nx.degree()]
    return max(degrees)

# %%
for vill_no in vill_list:

    # our observed network
    stata_household = pd.read_stata('banerjee_data/datav4.0/Data/2. Demographics and Outcomes/household_characteristics.dta')
    file = 'banerjee_data/datav4.0/Data/1. Network Data/Adjacency Matrices/adj_' + 'allVillageRelationships' +'_HH_vilno_' + str(vill_no) + '.csv'
    vill_mat = (pd.read_csv(file, header=None)).to_numpy()
    stata_vill = stata_household.where(stata_household['village'] == vill_no).dropna(how = 'all')
    room_type = np.array(stata_vill['room_no']/np.sqrt((stata_vill['bed_no']+1))<=2)
    room_type_dict = {k: int(v)*2 -1 for k, v in enumerate(room_type)}
    
    kappa_vill = get_max_degree(vill_mat)
    #print(kappa_vill)

    best_sc = -1
    best_ho = -1
    best_emd = np.inf

    for sc in sc_list:
        for ho in ho_list:
            data_dir = 'finer_results_ntwk'
            filename = '{odir}/{vill_no}_{k}_{sc}_{ho}_losses.txt'.format(
                odir=data_dir, vill_no=str(vill_no), k = str(k), sc = str(sc), ho = str(ho))

            f = open(filename, "r")

            # nonsense code for reading the simulated networks and attrs
            ntwk = f.readline()
            attrs = f.readline()
            ntwk = ntwk.replace('[', '')
            ntwk = ntwk.replace(']', '')
            ntwk = ntwk.replace("'", '')
            num_nodes = int(np.sqrt((ntwk.count('0.0') + ntwk.count('1.0'))/5))
            ntwk_arr = np.array([int(float(e)) for e in ntwk.split(',')])
            arr1 = ntwk_arr[:num_nodes**2].reshape((num_nodes, num_nodes))
            arr2 = ntwk_arr[num_nodes**2:2*num_nodes**2].reshape((num_nodes, num_nodes))
            arr3 = ntwk_arr[2*num_nodes**2:3*num_nodes**2].reshape((num_nodes, num_nodes))
            arr4 = ntwk_arr[3*num_nodes**2:4*num_nodes**2].reshape((num_nodes, num_nodes))
            arr5 = ntwk_arr[4*num_nodes**2:5*num_nodes**2].reshape((num_nodes, num_nodes))

            attrs = attrs.strip('{}\n')
            pairs = attrs.split(',')
            attr_dict = {int(key): int(value) for key, value in (pair.split(': ') for pair in pairs)}
            
            sim_dists = [ calc_dists(a, attr_dict, k) for a in [arr1, arr2, arr3, arr4, arr5] ]
            avg_sim_dists = avg_dists(sim_dists)
            vill_dist = calc_dists(vill_mat, room_type_dict, kappa_vill)
            
            sim_tri_count = np.mean([ triangle_count(np.array(a)) for a in [arr1, arr2, arr3, arr4, arr5] ])
            sim_assort = np.mean([ assortativity_coeff(np.array(a), attr_dict) for a in [arr1, arr2, arr3, arr4, arr5] ])
            
            vill_tri_count = triangle_count(vill_mat)
            vill_assort = assortativity_coeff(vill_mat, room_type_dict)
            
            
            curr_emd = ntwk_metric(avg_sim_dists, sim_tri_count, sim_assort, vill_dist, vill_tri_count, vill_assort)

            if curr_emd < best_emd:
                best_emd = curr_emd
                best_sc = sc
                best_ho = ho
                
    print('The best emd for village ', str(vill_no), ' is ', str(best_emd), ' for sc and ho ', str(best_sc), ', ', str(best_ho))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 55
#      51 vill_tri_count = triangle_count(vill_mat)
#      52 vill_assort = assortativity_coeff(vill_mat, room_type_dict)
# ---> 55 curr_emd = ntwk_metric(avg_sim_dists, sim_tri_count, sim_assort, vill_dist, vill_tri_count, vill_assort)
#      57 if curr_emd < best_emd:
#      58     best_emd = curr_emd
#
# Cell In[4], line 33, in ntwk_metric(dist1, tc1, assort1, dist2, tc2, assort2)
#      32 def ntwk_metric(dist1, tc1, assort1, dist2, tc2, assort2):
# ---> 33     distr_metric = emd(dist1, dist2)
#      35     tc_diff = abs(tc1 - tc2) / (tc1 + tc2) # https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error
#      36     assort_diff = abs(assort1 - assort2) / (assort1 + assort2)
#
# File ~/IESimulation/comparison/wasserstein.py:67, in emd(dist1, dist2, dist_func)
#      63 assert math.isclose(weight_const, 1), 'Total weight should be close to 1'
#      65 c = np.reshape(D, (n * m, ))
# ---> 67 res = linprog(c,
#      68     A_ub=ineq_const_mat,
#      69     b_ub=ineq_const_bounds,
#      70     A_eq=eq_const_mat,
#      71     b_eq=weight_const,
#      72     method='highs',
#      73     #bounds=(0, None)
#      74     bounds=(0, 1)
#      75 )
#      78 flows = res.x
#      79 obj_val = res.fun
#
# File ~/opt/anaconda3/envs/ies/lib/python3.11/site-packages/scipy/optimize/_linprog.py:639, in linprog(c, A_ub, b_ub, A_eq, b_eq, bounds, method, callback, options, x0, integrality)
#     634     raise NotImplementedError("HiGHS solvers do not support the "
#     635                               "callback interface.")
#     636 highs_solvers = {'highs-ipm': 'ipm', 'highs-ds': 'simplex',
#     637                  'highs': None}
# --> 639 sol = _linprog_highs(lp, solver=highs_solvers[meth],
#     640                      **solver_options)
#     641 sol['status'], sol['message'] = (
#     642     _check_result(sol['x'], sol['fun'], sol['status'], sol['slack'],
#     643                   sol['con'], lp.bounds, tol, sol['message'],
#     644                   integrality))
#     645 sol['success'] = sol['status'] == 0
#
# File ~/opt/anaconda3/envs/ies/lib/python3.11/site-packages/scipy/optimize/_linprog_highs.py:338, in _linprog_highs(lp, solver, time_limit, presolve, disp, maxiter, dual_feasibility_tolerance, primal_feasibility_tolerance, ipm_optimality_tolerance, simplex_dual_edge_weight_strategy, mip_rel_gap, mip_max_nodes, **unknown_options)
#     336 else:
#     337     A = np.vstack((A_ub, A_eq))
# --> 338 A = csc_matrix(A)
#     340 options = {
#     341     'presolve': presolve,
#     342     'sense': HIGHS_OBJECTIVE_SENSE_MINIMIZE,
#    (...)
#     358     'mip_rel_gap': mip_rel_gap,
#     359 }
#     360 options.update(unknown_options)
#
# File ~/opt/anaconda3/envs/ies/lib/python3.11/site-packages/scipy/sparse/_compressed.py:84, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      80     except Exception as e:
#      81         raise ValueError("unrecognized {}_matrix constructor usage"
#      82                          "".format(self.format)) from e
#      83     self._set_self(self.__class__(
# ---> 84         self._coo_container(arg1, dtype=dtype)
#      85     ))
#      87 # Read matrix dimensions given, if any
#      88 if shape is not None:
#
# File ~/opt/anaconda3/envs/ies/lib/python3.11/site-packages/scipy/sparse/_coo.py:195, in _coo_base.__init__(self, arg1, shape, dtype, copy)
#     192         raise ValueError('inconsistent shapes: %s != %s' %
#     193                          (shape, self._shape))
#     194 index_dtype = self._get_index_dtype(maxval=max(self._shape))
# --> 195 row, col = M.nonzero()
#     196 self.row = row.astype(index_dtype, copy=False)
#     197 self.col = col.astype(index_dtype, copy=False)
#
# KeyboardInterrupt:

# %%
#The best emd for village  10  is  0.13435163523262617  for sc and ho  0.0 ,  0.4375

# %%
for vill_no in vill_list:
    
    # let's try a different edge set

    stata_household = pd.read_stata('banerjee_data/datav4.0/Data/2. Demographics and Outcomes/household_characteristics.dta')

    # various edge sets
    #money_hyp_files = ['borrowmoney', 'lendmoney', 'keroricecome', 'keroricego']
    #trust_hyp_files = ['helpdecision', 'giveadvice', 'medic']
    trust_fact_files = ['visitcome','visitgo', 'templecompany', 'helpdecision', 'giveadvice', 'medic']


    # choose village and label with normalized room type
    stata_vill = stata_household.where(stata_household['village'] == vill_no).dropna(how = 'all')
    room_type = np.array(stata_vill['room_no']/np.sqrt((stata_vill['bed_no']+1))<=2)
    room_type_dict = {k: v for k, v in enumerate(room_type)}

    old_file3 = 'banerjee_data/datav4.0/Data/1. Network Data/Adjacency Matrices/adj_' + trust_fact_files[0] +'_HH_vilno_' + str(vill_no) + '.csv'
    ad_mat_old3 = (pd.read_csv(old_file3, header=None)).to_numpy()

    for file in trust_fact_files[1:]:
        new_file3 = 'banerjee_data/datav4.0/Data/1. Network Data/Adjacency Matrices/adj_' + file +'_HH_vilno_' + str(vill_no) + '.csv'
        ad_mat_new3= (pd.read_csv(new_file3, header=None)).to_numpy()

        ad_mat_old3 = np.bitwise_or(ad_mat_old3, ad_mat_new3)

    vill_mat = ad_mat_old3
    
    kappa_vill = get_max_degree(vill_mat)
    #print(kappa_vill)

    best_sc = -1
    best_ho = -1
    best_emd = np.inf

    
    best_sc = -1
    best_ho = -1
    best_emd = np.inf

    for sc in sc_list:
        for ho in ho_list:
            data_dir = 'finer_results_ntwk'
            filename = '{odir}/{vill_no}_{k}_{sc}_{ho}_losses.txt'.format(
                odir=data_dir, vill_no=str(vill_no), k = str(k), sc = str(sc), ho = str(ho))

            f = open(filename, "r")

            # nonsense code for reading the simulated networks and attrs
            ntwk = f.readline()
            attrs = f.readline()
            ntwk = ntwk.replace('[', '')
            ntwk = ntwk.replace(']', '')
            ntwk = ntwk.replace("'", '')
            num_nodes = int(np.sqrt((ntwk.count('0.0') + ntwk.count('1.0'))/5))
            ntwk_arr = np.array([int(float(e)) for e in ntwk.split(',')])
            arr1 = ntwk_arr[:num_nodes**2].reshape((num_nodes, num_nodes))
            arr2 = ntwk_arr[num_nodes**2:2*num_nodes**2].reshape((num_nodes, num_nodes))
            arr3 = ntwk_arr[2*num_nodes**2:3*num_nodes**2].reshape((num_nodes, num_nodes))
            arr4 = ntwk_arr[3*num_nodes**2:4*num_nodes**2].reshape((num_nodes, num_nodes))
            arr5 = ntwk_arr[4*num_nodes**2:5*num_nodes**2].reshape((num_nodes, num_nodes))

            attrs = attrs.strip('{}\n')
            pairs = attrs.split(',')
            attr_dict = {int(key): int(value) for key, value in (pair.split(': ') for pair in pairs)}
            
            sim_dists = [ calc_dists(a, attr_dict, k) for a in [arr1, arr2, arr3, arr4, arr5] ]
            avg_sim_dists = avg_dists(sim_dists)
            vill_dist = calc_dists(vill_mat, room_type_dict, kappa_vill)
            
            sim_tri_count = np.mean([ triangle_count(np.array(a)) for a in [arr1, arr2, arr3, arr4, arr5] ])
            sim_assort = np.mean([ assortativity_coeff(np.array(a), attr_dict) for a in [arr1, arr2, arr3, arr4, arr5] ])
            
            vill_tri_count = triangle_count(vill_mat)
            vill_assort = assortativity_coeff(vill_mat, room_type_dict)
            
            
            curr_emd = ntwk_metric(avg_sim_dists, sim_tri_count, sim_assort, vill_dist, vill_tri_count, vill_assort)

            if curr_emd < best_emd:
                best_emd = curr_emd
                best_sc = sc
                best_ho = ho
                
    print('The best emd for village ', str(vill_no), ' is ', str(best_emd), ' for sc and ho ', str(best_sc), ', ', str(best_ho))
# Out:
# The best emd for village  1  is  0.1040894494467567  for sc and ho  0.25 ,  0.3125
# The best emd for village  2  is  0.043332661651870455  for sc and ho  0.5625 ,  0.375
# The best emd for village  3  is  0.03743375225469291  for sc and ho  0.5 ,  0.375
# The best emd for village  4  is  0.02739861425849105  for sc and ho  0.5625 ,  0.4375
# The best emd for village  5  is  0.044036242973049256  for sc and ho  0.625 ,  0.625
# The best emd for village  6  is  0.041930727839502566  for sc and ho  0.375 ,  0.1875
# The best emd for village  7  is  0.11745745126679269  for sc and ho  0.1875 ,  0.375
# The best emd for village  8  is  0.04146182463484313  for sc and ho  0.25 ,  0.3125
# The best emd for village  9  is  0.12104972125128444  for sc and ho  0.25 ,  0.375
# The best emd for village  10  is  0.12282053560450493  for sc and ho  0.25 ,  0.4375
# The best emd for village  11  is  0.10822383424135519  for sc and ho  0.1875 ,  0.3125
# The best emd for village  12  is  0.08881110981174795  for sc and ho  0.4375 ,  0.4375
# The best emd for village  14  is  0.1057055596745351  for sc and ho  0.1875 ,  0.25
# The best emd for village  15  is  0.12147306638125452  for sc and ho  0.25 ,  0.3125
# The best emd for village  16  is  0.10817894798383695  for sc and ho  0.1875 ,  0.375
# The best emd for village  17  is  0.07960321886150985  for sc and ho  0.25 ,  0.3125
# The best emd for village  18  is  0.0847465566666091  for sc and ho  0.25 ,  0.375
# The best emd for village  19  is  0.07399593471631292  for sc and ho  0.1875 ,  0.25
# The best emd for village  20  is  0.04365828121756213  for sc and ho  0.4375 ,  0.3125
# The best emd for village  21  is  0.07003122512276848  for sc and ho  0.375 ,  0.5625
# The best emd for village  23  is  0.06270118607862034  for sc and ho  0.375 ,  0.5625
# The best emd for village  24  is  0.08609612514022226  for sc and ho  0.25 ,  0.4375
# The best emd for village  25  is  0.08050773227090491  for sc and ho  0.3125 ,  0.375
# The best emd for village  26  is  0.08378098700265474  for sc and ho  0.125 ,  0.3125
# The best emd for village  27  is  0.09981752020801025  for sc and ho  0.5625 ,  0.5625
# The best emd for village  28  is  0.13197197725934348  for sc and ho  0.5 ,  0.5625
# The best emd for village  29  is  0.07704195977808576  for sc and ho  0.4375 ,  0.4375
# The best emd for village  30  is  0.13031811469527424  for sc and ho  0.25 ,  0.3125
# The best emd for village  31  is  0.10043479692007541  for sc and ho  0.25 ,  0.3125
# The best emd for village  32  is  0.11417306281259323  for sc and ho  0.125 ,  0.25
# The best emd for village  33  is  0.1177221883311842  for sc and ho  0.25 ,  0.3125
# The best emd for village  34  is  0.10297929514356098  for sc and ho  0.3125 ,  0.3125
# The best emd for village  35  is  0.12458892308156941  for sc and ho  0.25 ,  0.375
# The best emd for village  36  is  0.13802677366012162  for sc and ho  0.0 ,  0.3125
# The best emd for village  37  is  0.12347993570514387  for sc and ho  0.125 ,  0.3125
# The best emd for village  38  is  0.0748413547733721  for sc and ho  0.625 ,  0.6875
# The best emd for village  39  is  0.11640559531990419  for sc and ho  0.1875 ,  0.3125
# The best emd for village  40  is  0.09562538314698488  for sc and ho  0.3125 ,  0.4375
# The best emd for village  41  is  0.09777686290685546  for sc and ho  0.1875 ,  0.25
# The best emd for village  42  is  0.11113392222207068  for sc and ho  0.25 ,  0.3125
# The best emd for village  43  is  0.13150722057845798  for sc and ho  0.1875 ,  0.3125
# The best emd for village  44  is  0.07584999397881781  for sc and ho  0.1875 ,  0.3125
# The best emd for village  45  is  0.07357258376219185  for sc and ho  0.25 ,  0.375
# The best emd for village  46  is  0.11162754814547488  for sc and ho  0.25 ,  0.375
# The best emd for village  47  is  0.12271858302785876  for sc and ho  0.125 ,  0.3125
# The best emd for village  48  is  0.11843143089515218  for sc and ho  0.1875 ,  0.4375
# The best emd for village  49  is  0.10300549887615706  for sc and ho  0.125 ,  0.375
# The best emd for village  50  is  0.13268641307681414  for sc and ho  0.0 ,  0.3125
# The best emd for village  51  is  0.23315168924055102  for sc and ho  0.0 ,  0.5625
# The best emd for village  52  is  0.22572910566818172  for sc and ho  0.0 ,  0.5625
# The best emd for village  53  is  0.1516724601266462  for sc and ho  0.0 ,  0.4375
# The best emd for village  54  is  0.15753102707540978  for sc and ho  0.0 ,  0.5
# The best emd for village  55  is  0.08190321268308465  for sc and ho  0.3125 ,  0.3125
# The best emd for village  56  is  0.1098946644959907  for sc and ho  0.3125 ,  0.3125
# The best emd for village  57  is  0.08776714089879764  for sc and ho  0.1875 ,  0.3125
# The best emd for village  58  is  0.09530973232652877  for sc and ho  0.375 ,  0.5625
# The best emd for village  59  is  0.12405431039843035  for sc and ho  0.25 ,  0.375
# The best emd for village  60  is  0.10139137675125087  for sc and ho  0.625 ,  0.6875
# The best emd for village  61  is  0.14330179883961153  for sc and ho  0.125 ,  0.3125
# The best emd for village  62  is  0.08842641247631741  for sc and ho  0.25 ,  0.375
# The best emd for village  63  is  0.0908124621929118  for sc and ho  0.3125 ,  0.3125
# The best emd for village  64  is  0.11023378899368341  for sc and ho  0.5 ,  0.5625
# The best emd for village  65  is  0.16599734117454687  for sc and ho  0.0 ,  0.375
# The best emd for village  66  is  0.09025454367687312  for sc and ho  0.4375 ,  0.5625
# The best emd for village  67  is  0.15873457304178756  for sc and ho  0.125 ,  0.375
# The best emd for village  68  is  0.14518297195774885  for sc and ho  0.25 ,  0.3125
# The best emd for village  69  is  0.24659640272231076  for sc and ho  0.0 ,  0.5
# The best emd for village  70  is  0.18206218174147298  for sc and ho  0.0 ,  0.3125
# The best emd for village  71  is  0.15566967838250295  for sc and ho  0.0625 ,  0.3125
# The best emd for village  72  is  0.09898090042403708  for sc and ho  0.25 ,  0.5
# The best emd for village  73  is  0.17298672057875672  for sc and ho  0.0 ,  0.3125
# The best emd for village  74  is  0.09285943239102434  for sc and ho  0.375 ,  0.375
# The best emd for village  75  is  0.176602364632297  for sc and ho  0.0 ,  0.375
# The best emd for village  76  is  0.12208012475309937  for sc and ho  0.5 ,  0.5625
# The best emd for village  77  is  0.13026497698422274  for sc and ho  0.1875 ,  0.3125
